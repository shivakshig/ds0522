# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv')

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn-whitegrid")

import seaborn as sns

from collections import Counter

import warnings
warnings.filterwarnings("ignore")

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
#we can see age of 75% population is 48 but max is 90 (Outliers seems to be present)
#Number of house working in majorly 45 but max is 99 (Outliers seems to be present here too)

# %%
fig, axes = plt.subplots(3,4, figsize=(16,15))
row = 0
column = 0

for i, feature in enumerate(df.select_dtypes(include='object')):
    sns.countplot(y=feature, data=df,ax= axes[row][column])
    if column == 3:
        column = 0
        row += 1
    else:
        column +=1
fig.tight_layout()
plt.show()

# %% [raw]
# #Major work class is private , # in relationship status max are husbands, # Population class is majorly of US,# There are more population who earn less than 50k.
# #Native country are heavily dominated by the variable "United States". Because of that, it might not be helpful in the model to help predict income group

# %%
fig, axes = plt.subplots(2,3, figsize=(16,15))
row = 0
column = 0

for i, feature in enumerate(df.select_dtypes(include=['int', 'float'])):
    sns.histplot(x=feature, data=df,ax= axes[row][column])
    if column == 2:
        column = 0
        row = 1
    else:
        column +=1
fig.tight_layout()
plt.show()

# %%
#Age is mostly from 30-60 , right skewed. #Cap gain and loss can be combined # Mostly working hhours per week is 40

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline


from sklearn.ensemble import RandomForestClassifier

# %%
numerics=['int8','int16','int32','int64','float16','float32','float64']
categorical_columns=[]
features=df.columns.values.tolist()

for col in features:
    if df[col].dtype in numerics:
        continue
    categorical_columns.append(col)

# %%
categorical_columns
# Out:
# ['Workclass',
#  'Education',
#  'Marital_status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Native_country',
#  'Income']

# %%
sns.countplot(df["Income"])
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(15,4))
sns.countplot(x="Age", hue="Income", data=df, palette="colorblind")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(15,4))
sns.countplot(x="Workclass", hue="Income", data=df, palette="colorblind")
# Out:
# <AxesSubplot:xlabel='Workclass', ylabel='count'>

# %%
#More income where work class is private and income > 50k

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(15,4))
sns.countplot(x="Education", hue="Income", data=df, palette="colorblind")
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
#Higher education group has income >50k

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x="Education_num", hue="Income", data=df, palette="colorblind")
# Out:
# <AxesSubplot:xlabel='Education_num', ylabel='count'>

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x="Marital_status", hue="Income", data=df, palette="colorblind")
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='count'>

# %%
#Married class has more income>50k

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x="Occupation", hue="Income", data=df, palette="colorblind")
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
#Certain occupation does have a higher proportion of individual earning more. And looking at the univariate analysis, the data is fairly well distribution between the different classes. This further suggest that this feature may be useful.

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x="Relationship", hue="Income", data=df, palette="colorblind")
# Out:
# <AxesSubplot:xlabel='Relationship', ylabel='count'>

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x="Race", hue="Income", data=df, palette="colorblind")
# Out:
# <AxesSubplot:xlabel='Race', ylabel='count'>

# %%
#Whites have higher income

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x="Sex", hue="Income", data=df, palette="colorblind")
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
#Male domination can be seen in income

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x="Native_country", hue="Income", data=df, palette="colorblind")
# Out:
# <AxesSubplot:xlabel='Native_country', ylabel='count'>

# %%
#The native country column does have different proportion of income group, however, the differences does not look visually big. On top of that, in the univariate analysis, we uncovered that the data is heavily dominated by United States. This further suggest that this column will likely not be useful in the data modeling

# %%
plt.subplots(figsize=(15,4))
sns.countplot(x="Sex", hue="Income", data=df, palette="colorblind")
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
#Cap gain and Cap loss can be combined as if one can have gain, other can have loss too

# %%
df_sub = pd.crosstab(index=df['Hours_per_week'],
                    columns=df['Income'],
                    normalize="index")
df_sub.plot(kind='bar', 
                stacked=True, 
                colormap='tab10', figsize=(20,15))
# Out:
# <AxesSubplot:xlabel='Hours_per_week'>

# %%
#Longer working hours does not necessarily equates to higher income

# %%
#NOW LETS APPLY HEAT MAP TO CHECK INTER FEATURES RELATIONSHIP

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#No correlation can be seen

# %%
#Lets now encode data

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
for column in categorical_columns:
    df[column] = label.fit_transform(df[column])

# %%
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 3       28          4  338409          9             13               2
# 4       37          4  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
X = df.drop('Income', 1)
y = df['Income']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=47)
X_train.shape, X_test.shape
# Out:
# ((21164, 14), (11396, 14))

# %%
X_test, X_validation, y_test, y_validation = train_test_split(X_test, y_test, test_size=0.20, random_state=47)
X_test.shape, X_validation.shape
# Out:
# ((9116, 14), (2280, 14))

# %%
#Scaling the data

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = pd.DataFrame(scaler.fit_transform(X_train), columns = X.columns)

X_test = pd.DataFrame(scaler.transform(X_test), columns = X.columns)
X_train.head()
# Out:
#         Age  Workclass    Fnlwgt  Education  Education_num  Marital_status  \
# 0 -1.001280   0.091880 -0.491549  -0.331977       1.138032        0.919273
# 1  1.491807   0.091880  1.718032   0.184315      -0.418244        2.243541
# 2 -0.927954   0.091880 -0.527954   0.184315      -0.418244        0.919273
# 3  0.978524   0.091880  0.969862  -1.622708      -2.752658        0.919273
# 4 -0.048041  -1.955012  0.675674   1.216900      -0.029175       -0.404996
#
#    Occupation  Relationship      Race       Sex  Capital_gain  Capital_loss  \
# 0    0.807629     -0.277004  0.394754  0.699478     -0.146053     -0.216464
# 1   -1.322092      1.586281  0.394754 -1.429638     -0.146053     -0.216464
# 2    0.097722      0.344091  0.394754  0.699478     -0.146053     -0.216464
# 3   -0.138913     -0.277004  0.394754 -1.429638     -0.146053     -0.216464
# 4   -1.322092     -0.898099  0.394754  0.699478     -0.146053     -0.216464
#
#    Hours_per_week  Native_country
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
LR = LogisticRegression()
LR.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = LR.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8304080737165423

# %%
from sklearn.decomposition import PCA
pca = PCA()

# %%
X_train = pca.fit_transform(X_train)
pca.explained_variance_ratio_
# Out:
# array([0.15047547, 0.10136825, 0.0900566 , 0.08041134, 0.07602039,
#        0.07329653, 0.06803126, 0.0663847 , 0.0616149 , 0.0606348 ,
#        0.053231  , 0.04925171, 0.04191131, 0.02731172])

# %%
##Only 2.75% of variance is explained by the last variable. So, we can assume that it carries little information

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()

dt.fit(X_train,y_train)

print("The score is: ", dt.score(X_test,y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [114], in <cell line: 1>()
# ----> 1 lr_yprad = lr.predict(X_test)
#       2 knn_yprad = knn.predict(X_test)
#       3 dt_yprad = dt.predict(X_test)
#
# NameError: name 'lr' is not defined

# %%
#RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=200)

rf.fit(X_train,y_train)

print("THE SCORE IS: ",rf.score(X_test,y_test))
# Out:
# THE SCORE IS:  0.8581081081081081

# %%
#KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)

knn.fit(X_train,y_train)

pred_for_knn = knn.predict(X_test)

print("KNN SCORE IS: ",knn.score(X_test, y_test))
# Out:
# KNN SCORE IS:  0.7536855036855037

# %%
#WE HAVE SEEN BEST SCORE IS IN RANDOM FOREST,SO WE CAN SELECT THE SAME

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import plot_roc_curve

# %%
lr=LogisticRegression() #Logistic Regression
knn=KNeighborsClassifier() #KNearest Neibour 
dt=DecisionTreeClassifier() # Deciesion Tree
rf=RandomForestClassifier() # Random Forest

# %%
lr.fit(X_train, y_train)
knn.fit(X_train,y_train)
dt.fit(X_train,y_train)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
print("Lr classification score",lr.score(X_train,y_train))
print("knn classification score",knn.score(X_train,y_train))
print("dt classification score",dt.score(X_train,y_train))
print("rf classification score",rf.score(X_train,y_train))
# Out:
# Lr classification score 0.7922516672516673
# knn classification score 0.8308178308178308
# dt classification score 1.0
# rf classification score 0.999956124956125

# %%
lr_yprad = lr.predict(X_test)
knn_yprad = knn.predict(X_test)
dt_yprad = dt.predict(X_test)
rf_yprad = rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lr_conf_mat = confusion_matrix(y_test,lr_yprad)
print("confusion matrix for lr_model",'\n',lr_conf_mat)
# Out:
# confusion matrix for lr_model
#  [[7277  177]
#  [1816  498]]

# %%
knn_conf_mat = confusion_matrix(y_test,knn_yprad)
print("confusion matrix for knn_model",'\n',knn_conf_mat)
# Out:
# confusion matrix for knn_model
#  [[6871  583]
#  [1610  704]]

# %%
dt_conf_mat = confusion_matrix(y_test,dt_yprad)
print("confusion matrix for dt_model",'\n',dt_conf_mat)
# Out:
# confusion matrix for dt_model
#  [[6537  917]
#  [ 882 1432]]

# %%
rf_conf_mat = confusion_matrix(y_test,rf_yprad)
print("confusion matrix for lr_model",'\n',rf_conf_mat)
# Out:
# confusion matrix for lr_model
#  [[6925  529]
#  [ 882 1432]]

# %%
lr_report = classification_report(y_test,lr_yprad)
print(" lr classification_report" ,'\n',lr_report)

knn_report = classification_report(y_test,knn_yprad)
print(" knn classification_report" ,'\n',knn_report)

dt_report = classification_report(y_test,dt_yprad)
print(" dt classification_report" ,'\n',dt_report)


rf_report = classification_report(y_test,rf_yprad)
print(" rf classification_report" ,'\n',rf_report)
# Out:
#  lr classification_report
#                precision    recall  f1-score   support
#
#            0       0.80      0.98      0.88      7454
#            1       0.74      0.22      0.33      2314
#
#     accuracy                           0.80      9768
#    macro avg       0.77      0.60      0.61      9768
# weighted avg       0.79      0.80      0.75      9768
#
#  knn classification_report
#                precision    recall  f1-score   support
#
#            0       0.81      0.92      0.86      7454
#            1       0.55      0.30      0.39      2314
#
#     accuracy                           0.78      9768
#    macro avg       0.68      0.61      0.63      9768
# weighted avg       0.75      0.78      0.75      9768
#
#  dt classification_report
#                precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88      7454
#            1       0.61      0.62      0.61      2314
#
#     accuracy                           0.82      9768
# ...

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import plot_roc_curve
print(roc_auc_score(y_test,lr.predict(X_test)))
print(roc_auc_score(y_test,knn.predict(X_test)))
print(roc_auc_score(y_test,dt.predict(X_test)))
print(roc_auc_score(y_test,rf.predict(X_test)))
# Out:
# 0.5957330573063624
# 0.6130110253867048
# 0.7479103178260256
# 0.7739366124329481

# %%
disp = plot_roc_curve(dt,X_test,y_test)
plot_roc_curve(lr,X_test,y_test,ax=disp.ax_)  # here ax_ for axis with confustion matrics
plot_roc_curve(knn,X_test,y_test,ax=disp.ax_)
plot_roc_curve(dt,X_test,y_test,ax=disp.ax_)
plot_roc_curve(rf,X_test,y_test,ax=disp.ax_)
