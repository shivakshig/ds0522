# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv('C:/Users/MIDAS/Desktop/IBM_HR_Attrition_Rate_Analytics.csv')

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#our target is Attrition and others are features to it, so lets first plot the graphs to see the impact of features on attrition

# %%
#using countplot

# %%
sns.countplot(data["Attrition"])
# Out:
# C:\Users\MIDAS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
#% OF ATTRITION IS HIGH, LETS COMPARE TO FEATURES

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(12,4))
sns.countplot(x="Age", hue="Attrition", data=data, palette="colorblind")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
# LET US FIRST CHECK ALL FEATURES INDIVIDUALLY

# %%
sns.barplot(x = 'Gender',
            y = 'MonthlyRate',
            data = data)

plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,7))
sns.violinplot(x='Gender', y='MonthlyIncome',hue='Attrition',split=True,data=data)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='MonthlyIncome'>

# %%
# NOT MUCH DIFF BW MALE AND FEMALE W.r.t Attrition, NOW LETS CHECK AGE

# %%
plt.figure(figsize=(20,5))
plt.hist(data.Age,bins=15)
plt.xlabel("Age")
plt.ylabel("Counts")
plt.title("Age OF EMPLOYEE")
plt.show()

# %%
# WE CAN SEE MAX EMPLOYEE BETWEEN 30 TO 40 YEAR OLD

# %%
# NOW LETS CHECK RELATIONSHIP OF AGE , INCOME AND ATTRITION

# %%
plt.style.use('ggplot')
g = sns.pairplot(data, vars=["MonthlyIncome", "Age"],hue="Attrition")

# %%
#Younger empoyees are more likely to leave for opportunities as compared to older employee
#Employee with lower income 5-10k are more likely to leave

# %%
#Education field - check

# %%
labels=data.EducationField.value_counts().index
sizes=data.EducationField.value_counts().values
plt.figure
plt.pie(sizes,labels=labels,shadow = True )
plt.title("Education Field Counts")
# Out:
# Text(0.5, 1.0, 'Education Field Counts')

# %%
#MAJORITY ARE LIFE SCIENCE EDUCATED, THEN MEDICAL

# %%
sns.countplot(x='Attrition', hue= 'EducationField', data = data)
plt.show()

# %%
#We can see that employees with life science and medical degrees tend more for attrition, may be because number of employees are of the same group

# %%
sns.countplot(data['JobRole'])
fig = plt.gcf()
fig.set_size_inches(20,6)
plt.title('Job Role')
# Out:
# C:\Users\MIDAS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Job Role')

# %%
#MAX EMPLOYEES ARE SALES EXECUTIVE

# %%
plt.figure(figsize=(8,6))
data.MaritalStatus.value_counts().plot(kind='bar')
plt.show()

# %%
#MAX EMPLOYEES ARE MARRIED, LETS SEE STATUS Wrt ATTRITION

# %%
sns.countplot(x='Attrition', hue= 'MaritalStatus', data = data)
plt.show()

# %%
#SINGLES ARE MORE LIKELY TO CHANGE JOB, DUE TO LOW RESPONSIBILITY MAY BE

# %%
plt.figure(figsize=(4,2))
plt.style.use('ggplot')
sns.jointplot(x='TotalWorkingYears', y='MonthlyIncome', data=data)

# %%
# NUMBER OF WORKING YEAR TO NCOME, MORE THE EXP HIGHER THE INCOME

# %%
palette = sns.color_palette("rocket_r")
sns.lmplot(x = 'TotalWorkingYears', y = 'MonthlyIncome', data = data, palette = palette, col = 'Attrition')
plt.show()

# %%
sns.countplot(x='Attrition', hue= 'DistanceFromHome', data = data)
plt.show()

# %%
#Higher the distance more the attrition,#MORE WORKING YEARS ARE MORE ATTACHED TO COMPANY

# %%
import seaborn as sns

# %%
data.hist(figsize=(20,20))
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(12,4))
sns.countplot(x="EnvironmentSatisfaction", hue="Attrition", data=data, palette="colorblind")
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(12,4))
sns.countplot(x="TrainingTimesLastYear", hue="Attrition", data=data)
# Out:
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='count'>

# %%
#AT 2 and 3 trainings attrition rate is highest

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(12,4))
sns.countplot(x="YearsAtCompany", hue="Attrition", data=data)
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='count'>

# %%
#Max attrition is at 1st year with time company relationship gets better

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(12,4))
sns.countplot(x="YearsInCurrentRole", hue="Attrition", data=data)
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='count'>

# %%
#Max Attrition for new  employees, with no of years in same role increases Attrition reduces

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(12,4))
sns.countplot(x="PercentSalaryHike", hue="Attrition", data=data)
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='count'>

# %%
#With high %age hike Attrition reduces

# %%
import pandas as pd, numpy as np, seaborn as sns, plotly.express as px, xgboost as XGB, matplotlib.pyplot as plt,plotly.graph_objects as go, math
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.preprocessing import MinMaxScaler, OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score
import warnings
warnings.filterwarnings("ignore")
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 import pandas as pd, numpy as np, seaborn as sns, plotly.express as px, xgboost as XGB, matplotlib.pyplot as plt,plotly.graph_objects as go, math
#       2 from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
#       3 from sklearn.preprocessing import MinMaxScaler, OrdinalEncoder, OneHotEncoder
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
Attrition = data.query("Attrition == 'Yes'")
Attrition
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 21     36       Yes      Travel_Rarely       1218                   Sales
# 24     34       Yes      Travel_Rarely        699  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1438   23       Yes  Travel_Frequently        638                   Sales
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
def barplot(i):
    fig = px.histogram(Attrition, x = Attrition[i],
                      title = f'Attrition x {i}')
    fig.show()

# %%
barplot('EnvironmentSatisfaction')
barplot('JobInvolvement')
barplot('JobSatisfaction')
barplot('WorkLifeBalance')
barplot('PerformanceRating')
barplot('JobRole')
barplot('MaritalStatus')
barplot('RelationshipSatisfaction')
barplot('OverTime')
# Out:
# <div>                            <div id="278df8cc-d80d-4193-9994-01c70e1ffd8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("278df8cc-d80d-4193-9994-01c70e1ffd8f")) {                    Plotly.newPlot(                        "278df8cc-d80d-4193-9994-01c70e1ffd8f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"EnvironmentSatisfaction=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[2,4,3,3,2,2,4,2,1,1,2,1,3,4,3,3,4,3,1,2,2,4,4,2,1,1,3,2,2,2,2,2,4,4,3,3,3,3,1,4,1,3,1,1,4,1,4,3,3,1,4,2,1,4,1,3,3,1,3,3,1,1,4,3,1,2,1,1,2,3,2,2,3,4,1,2,2,3,1,4,1,1,2,1,3,4,2,4,4,3,2,1,4,3,3,3,3,4,2,1,4,3,4,2,2,4,3
# ...

# %%
#LETS ENCODE THE DATA NOW, SINCE WE HAVE CATEGORICAL DATA

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.preprocessing import MinMaxScaler, OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score

# %%
X = data.drop('Attrition', axis = 1)
y = data.Attrition

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3)
print('X train size: ', len(X_train))
print('X test size: ', len(X_test))
print('y train size: ', len(y_train))
print('y test size: ', len(y_test))
# Out:
# X train size:  1029
# X test size:  441
# y train size:  1029
# y test size:  441

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
OE=OrdinalEncoder()

# %%
numerics=['int8','int16','int32','int64','float16','float32','float64']
categorical_columns=[]
features=data.columns.values.tolist()

for col in features:
    if data[col].dtype in numerics:
        continue
    categorical_columns.append(col)

# %%
categorical_columns
# Out:
# ['Attrition']

# %%
categorical_columns.remove('Attrition')

# %%
from sklearn.preprocessing import LabelEncoder

label = LabelEncoder()
for column in categorical_columns:
    data[column] = label.fit_transform(data[column])

# %%
data
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
data
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
Scaler = MinMaxScaler()
Scaling_Cols = ['TrainingTimesLastYear','YearsAtCompany','TotalWorkingYears',
               'YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager',
               'PercentSalaryHike','Age','DailyRate','DistanceFromHome','HourlyRate',
               'MonthlyIncome','MonthlyRate','NumCompaniesWorked']
X_train[Scaling_Cols] = Scaler.fit_transform(X_train[Scaling_Cols])
X_test[Scaling_Cols] = Scaler.transform(X_test[Scaling_Cols])
X_train
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 1333  0.666667               2   0.824499           2          0.321429
# 683   0.166667               2   0.547278           2          0.642857
# 104   0.452381               0   0.671203           1          0.035714
# 1223  0.690476               1   0.709169           2          0.285714
# 462   0.380952               2   0.111032           2          0.714286
# ...        ...             ...        ...         ...               ...
# 30    0.357143               2   0.588109           1          0.035714
# 380   0.142857               2   0.908309           2          0.321429
# 1125  0.261905               1   0.638968           1          0.035714
# 1133  0.595238               2   0.635387           1          0.928571
# 270   0.880952               2   0.250000           1          0.000000
#
#       Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# ...

# %%
# Changing y values
print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# No     869
# Yes    160
# Name: Attrition, dtype: int64
# No     364
# Yes     77
# Name: Attrition, dtype: int64

# %%
y_train.replace({'No':0,
                'Yes':1}, inplace = True)
y_test.replace({'No':0,
                'Yes':1}, inplace = True)

# %%
print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# 0    869
# 1    160
# Name: Attrition, dtype: int64
# 0    364
# 1     77
# Name: Attrition, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# %%
X_train,y_train = SMOTE().fit_resample(X_train,y_train)

# %%
y_train.value_counts()
# Out:
# 1    869
# 0    869
# Name: Attrition, dtype: int64

# %%
#PREDICTING NOW

# %%
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [109], in <cell line: 3>()
#       1 from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier, GradientBoostingClassifier
#       2 from sklearn.tree import DecisionTreeClassifier
# ----> 3 from xgboost import XGBClassifier
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
adaboost = AdaBoostClassifier()
randomforest = RandomForestClassifier()
gradientboosting = GradientBoostingClassifier()
decisiontree = DecisionTreeClassifier()
xgboost =  XGBClassifier()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [110], in <cell line: 5>()
#       3 gradientboosting = GradientBoostingClassifier()
#       4 decisiontree = DecisionTreeClassifier()
# ----> 5 xgboost =  XGBClassifier()
#
# NameError: name 'XGBClassifier' is not defined

# %%
def predict(model):
    model.fit(X_train, y_train)
    y_predict = model.predict(X_test)
    print('Accuracy: %.2f%%' % (accuracy_score(y_test, y_predict) * 100 ))
    print('Precision: %.2f%%' % (precision_score(y_test, y_predict) * 100))
    print('Recall: %.2f%%' % (recall_score(y_test, y_predict) * 100))
    print('F1_Score: %.2f%%' % (f1_score(y_test, y_predict) * 100))
    confusion_matrix_model = confusion_matrix(y_test, y_predict)
    plt.figure(figsize=(12,8))
    ax = plt.subplot()
    sns.heatmap(confusion_matrix_model, annot=True, fmt='g', ax = ax)
    ax.set_xlabel('Predicted Label')
    ax.set_ylabel('Actual Label')
    ax.set_title(f'Confusion Matrix - {model}')
    ax.xaxis.set_ticklabels(['0','1'])
    ax.yaxis.set_ticklabels(['0','1'])

# %%
predict(decisiontree)
# Out:
# Accuracy: 74.83%
# Precision: 32.65%
# Recall: 41.56%
# F1_Score: 36.57%

# %%
predict(randomforest)
# Out:
# Accuracy: 85.03%
# Precision: 62.22%
# Recall: 36.36%
# F1_Score: 45.90%

# %%
predict(adaboost)
# Out:
# Accuracy: 82.09%
# Precision: 48.86%
# Recall: 55.84%
# F1_Score: 52.12%

# %%
predict(gradientboosting)
# Out:
# Accuracy: 82.99%
# Precision: 51.79%
# Recall: 37.66%
# F1_Score: 43.61%

# %%
#HYPERPARAMETER

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
randomforest_grid = {'n_estimators' : [100,150,200,250,300,350,400,450,500],
                    'max_depth':[5,1,15,20,25,30,40,50],
                    'criterion': ['gini','entropy'],
                    'min_samples_leaf':[2,5,8,10],
                    'min_samples_split': [2,5,8,10],
                    'max_features':['auto','sqrt']}
rf_tuning = RandomForestClassifier()
rf_search = RandomizedSearchCV(rf_tuning,param_distributions = randomforest_grid,
                              cv = 10, n_iter = 10, n_jobs = 1, verbose = 1, scoring = 'recall')
rf_search.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# C:\Users\MIDAS\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning:
#
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#
# C:\Users\MIDAS\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning:
#
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#
# C:\Users\MIDAS\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning:
#
# ...

# %%
rf_search.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_features': 'auto',
#  'max_depth': 40,
#  'criterion': 'entropy'}

# %%
tuned_rf = RandomForestClassifier(**rf_search.best_params_)
tuned_rf.fit(X_train,y_train)
y_pred = tuned_rf.predict(X_test)
print('Accuracy: %.2f%%' % (accuracy_score(y_test, y_pred) * 100 ))
print('Precision: %.2f%%' % (precision_score(y_test, y_pred) * 100))
print('Recall: %.2f%%' % (recall_score(y_test, y_pred) * 100))
print('F1_Score: %.2f%%' % (f1_score(y_test, y_pred) * 100))
confusion_matrix_model = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,8))
ax = plt.subplot()
sns.heatmap(confusion_matrix_model, annot=True, fmt='g', ax = ax)
ax.set_xlabel('Predicted Label')
ax.set_ylabel('Actual Label')
ax.set_title('Confusion Matrix - tuned random forest')
ax.xaxis.set_ticklabels(['0','1'])
ax.yaxis.set_ticklabels(['0','1'])
# Out:
# C:\Users\MIDAS\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning:
#
# `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
# Accuracy: 84.35%
# Precision: 59.52%
# Recall: 32.47%
# F1_Score: 42.02%
# [Text(0, 0.5, '0'), Text(0, 1.5, '1')]

# %%
grid = {'n_estimators' : [50,100,500,1500,2000],
       'learning_rate' : [0.05,0.1,1.0,0.15,0.2,1.5,2.0],
       'algorithm': ['SAMME', 'SAMME.R']}

adaboost = RandomizedSearchCV(AdaBoostClassifier(),
                             param_distributions = grid,
                             cv = 10,
                             n_iter = 10,
                              n_jobs = 1, 
                              verbose = 1, 
                              scoring = 'recall')
adaboost.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# RandomizedSearchCV(cv=10, estimator=AdaBoostClassifier(), n_jobs=1,
#                    param_distributions={'algorithm': ['SAMME', 'SAMME.R'],
#                                         'learning_rate': [0.05, 0.1, 1.0, 0.15,
#                                                           0.2, 1.5, 2.0],
#                                         'n_estimators': [50, 100, 500, 1500,
#                                                          2000]},
#                    scoring='recall', verbose=1)

# %%
adaboost.best_params_
# Out:
# {'n_estimators': 100, 'learning_rate': 1.0, 'algorithm': 'SAMME'}

# %%
tuned_adaboost = AdaBoostClassifier(**adaboost.best_params_)
tuned_adaboost.fit(X_train,y_train)
y_pred = tuned_adaboost.predict(X_test)
print('Accuracy: %.2f%%' % (accuracy_score(y_test, y_pred) * 100 ))
print('Precision: %.2f%%' % (precision_score(y_test, y_pred) * 100))
print('Recall: %.2f%%' % (recall_score(y_test, y_pred) * 100))
print('F1_Score: %.2f%%' % (f1_score(y_test, y_pred) * 100))
confusion_matrix_model = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,8))
ax = plt.subplot()
sns.heatmap(confusion_matrix_model, annot=True, fmt='g', ax = ax)
ax.set_xlabel('Predicted Label')
ax.set_ylabel('Actual Label')
ax.set_title('Confusion Matrix - tuned adaboost')
ax.xaxis.set_ticklabels(['0','1'])
ax.yaxis.set_ticklabels(['0','1'])
# Out:
# Accuracy: 82.09%
# Precision: 48.91%
# Recall: 58.44%
# F1_Score: 53.25%
# [Text(0, 0.5, '0'), Text(0, 1.5, '1')]

# %%
from sklearn.model_selection import train_test_split

X = data.drop('Attrition', axis=1)
y = data.Attrition

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
def print_score(clf, X_train, y_train, X_test, y_test, train=True):
    if train:
        pred = clf.predict(X_train)
        clf_report = pd.DataFrame(classification_report(y_train, pred, output_dict=True))
        print("Train Result:\n================================================")
        print(f"Accuracy Score: {accuracy_score(y_train, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_train, pred)}\n")
        
    elif train==False:
        pred = clf.predict(X_test)
        clf_report = pd.DataFrame(classification_report(y_test, pred, output_dict=True))
        print("Test Result:\n================================================")        
        print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"CLASSIFICATION REPORT:\n{clf_report}")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_test, pred)}\n")

# %%
#Conclusion- we use random forest as it gives best accuracy
