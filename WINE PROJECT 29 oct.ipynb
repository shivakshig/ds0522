# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScalar
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliners_influence import variance_inflation_factor
from sklearn.metrics import accuracy_score,confusion_matrix, roc_curve, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns 

import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [22], in <cell line: 3>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from sklearn.preprocessing import StandardScalar
#       4 from sklearn.linear_model import LogisticRegression
#       5 from sklearn.model_selection import train_test_split
#
# ImportError: cannot import name 'StandardScalar' from 'sklearn.preprocessing' (C:\Users\MIDAS\anaconda3\lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
from collections import Counter
Counter(df['quality'])
# Out:
# Counter({5: 681, 6: 638, 7: 199, 4: 53, 8: 18, 3: 10})

# %%
X=df.drop("quality",axis=1)
y=df.quality

# %%
import seaborn as sns

# %%
sns.scatterplot(x='fixed acidity',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %%
# fixed acidity equally distributed between 3 to 13

# %%
sns.scatterplot(x='volatile acidity',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>

# %%
# volatile acidity equally distributed between 0.2 to 1.1

# %%
sns.scatterplot(x='citric acid',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %%
# citric acid equally distributed between 0.0 to 0.8

# %%
sns.scatterplot(x='residual sugar',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='quality'>

# %%
sns.scatterplot(x='chlorides',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='quality'>

# %%
# citric acid equally distributed between 0.0 to 0.5

# %%
sns.scatterplot(x='free sulfur dioxide',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='quality'>

# %%
# free sulferdioxide equally distributed between 0 to 55

# %%
sns.scatterplot(x='total sulfur dioxide',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='quality'>

# %%
cc

# %%
sns.scatterplot(x='density',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %%
# density equally distributed between 0.991 to 1.002

# %%
sns.scatterplot(x='pH',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
# pH equally distributed between 2.9 to 3.8

# %%
sns.scatterplot(x='sulphates',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='quality'>

# %%
# sulphates equally distributed between 0.3 to 1.5

# %%
sns.scatterplot(x='alcohol',y='quality',data=df)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %%
# alcohol equally distributed between 9 to 14

# %%
#CORRELATION

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
df.corr()['quality'].sort_values()
# Out:
# volatile acidity       -0.390558
# total sulfur dioxide   -0.185100
# density                -0.174919
# chlorides              -0.128907
# pH                     -0.057731
# free sulfur dioxide    -0.050656
# residual sugar          0.013732
# fixed acidity           0.124052
# citric acid             0.226373
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# alcohol is 48% correlated to quality
#sulphates id 25% correlated
#pH is -5% correlated (negetively)
#density is -17% correlated
#total sulfur dioxide is -19% correlated
#free sulfer dioxise is -5.1% correlated
#Chlorides is -13% correlated
#residual sugar is 1.4% correlated
#citric acid is 23% correlated
#volatile acidity is -39% correlated
#fixed acidity is 12% correlated

# %%
from collections import Counter
Counter(df['quality'])
# Out:
# Counter({5: 681, 6: 638, 7: 199, 4: 53, 8: 18, 3: 10})

# %%
X=df.drop("quality",axis=1)
y=df.quality

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.75,random_state=41)

# %%
Counter(y_train)
# Out:
# Counter({5: 524, 6: 470, 4: 42, 7: 142, 8: 14, 3: 7})

# %%
import six
import joblib
import sys
sys.modules['sklearn.externals.six']=six
sys.modules['sklearn.exterals.joblib']=joblib

# %%
# !pip install scikit-learn

# %%
from imblearn.over_sampling import SMOTE

# %%
ove_smp=SMOTE(0.75)

# %%
# OUTLIERS CHECK

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_features=df.drop('quality',axis=1)

# %%
plt.figure(figsize=(20,25),facecolor='blue')
plotnumber=1

for column in df_features:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.boxplot(data=df_features[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
    
plt.show()

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
# outliers >0.65

# %%
sns.distplot(df['fixed acidity'])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %%
sns.distplot(df['volatile acidity'])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %%
sns.distplot(df['citric acid'])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %%
sns.distplot(df['residual sugar'])
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Density'>

# %%
sns.distplot(df['chlorides'])
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %%
sns.distplot(df['free sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(df['total sulfur dioxide'])
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(df['density'])
# Out:
# <AxesSubplot:xlabel='density', ylabel='Density'>

# %%
sns.distplot(df['pH'])
# Out:
# <AxesSubplot:xlabel='pH', ylabel='Density'>

# %%
sns.distplot(df['sulphates'])
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Density'>

# %%
sns.distplot(df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
df.corr()['quality']
# Out:
# fixed acidity           0.124052
# volatile acidity       -0.390558
# citric acid             0.226373
# residual sugar          0.013732
# chlorides              -0.128907
# free sulfur dioxide    -0.050656
# total sulfur dioxide   -0.185100
# density                -0.174919
# pH                     -0.057731
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
# very low correlation- residual sugar,pH, free sulfir dioxide

# %%
df=df.drop(['residual sugar','pH','free sulfur dioxide'],axis=1)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  chlorides  \
# 0               7.4             0.700         0.00      0.076
# 1               7.8             0.880         0.00      0.098
# 2               7.8             0.760         0.04      0.092
# 3              11.2             0.280         0.56      0.075
# 4               7.4             0.700         0.00      0.076
# ...             ...               ...          ...        ...
# 1594            6.2             0.600         0.08      0.090
# 1595            5.9             0.550         0.10      0.062
# 1596            6.3             0.510         0.13      0.076
# 1597            5.9             0.645         0.12      0.075
# 1598            6.0             0.310         0.47      0.067
#
#       total sulfur dioxide  density  sulphates  alcohol  quality
# 0                     34.0  0.99780       0.56      9.4        5
# 1                     67.0  0.99680       0.68      9.8        5
# ...

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  chlorides  \
# 0               7.4             0.700         0.00      0.076
# 1               7.8             0.880         0.00      0.098
# 2               7.8             0.760         0.04      0.092
# 3              11.2             0.280         0.56      0.075
# 4               7.4             0.700         0.00      0.076
# ...             ...               ...          ...        ...
# 1594            6.2             0.600         0.08      0.090
# 1595            5.9             0.550         0.10      0.062
# 1596            6.3             0.510         0.13      0.076
# 1597            5.9             0.645         0.12      0.075
# 1598            6.0             0.310         0.47      0.067
#
#       total sulfur dioxide  density  sulphates  alcohol  quality
# 0                     34.0  0.99780       0.56      9.4        5
# 1                     67.0  0.99680       0.68      9.8        5
# ...

# %%
#REMOVING OUTLIERS

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (1599, 9)

# %%
threshold=3
print (np.where(z>3))
# Out:
# (array([  13,   15,   17,   17,   19,   38,   42,   43,   81,   81,   83,
#          86,   88,   91,   92,  106,  106,  109,  120,  126,  127,  142,
#         144,  147,  151,  151,  151,  169,  169,  181,  199,  226,  226,
#         240,  243,  244,  258,  258,  281,  291,  339,  340,  347,  354,
#         374,  381,  391,  442,  442,  451,  459,  467,  480,  515,  517,
#         544,  554,  554,  555,  555,  557,  557,  568,  588,  591,  608,
#         614,  636,  639,  649,  651,  652,  652,  672,  672,  684,  690,
#         690,  692,  692,  723,  724,  730,  754,  776,  777,  795,  821,
#         832,  836,  837,  889,  899, 1017, 1018, 1051, 1051, 1079, 1081,
#        1114, 1165, 1244, 1260, 1269, 1269, 1270, 1270, 1288, 1289, 1299,
#        1299, 1312, 1319, 1319, 1367, 1370, 1370, 1372, 1372, 1374, 1374,
#        1434, 1435, 1469, 1474, 1476, 1478, 1493, 1496, 1505, 1558, 1570],
#       dtype=int64), array([6, 4, 3, 6, 3, 1, 3, 6, 3, 6, 3, 6, 6, 6, 6, 3, 6, 4, 1, 1, 1, 7,
# ...

# %%
import numpy as np
len(np.where(z>3)[0])
# Out:
# 132

# %%
z.iloc[4]
# Out:
# fixed acidity           0.528360
# volatile acidity        0.961877
# citric acid             1.391472
# chlorides               0.243707
# total sulfur dioxide    0.379133
# density                 0.558274
# sulphates               0.579207
# alcohol                 0.960246
# quality                 0.787823
# Name: 4, dtype: float64

# %%
df.shape
# Out:
# (1599, 9)

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (1491, 9)

# %%
(1599-1491)/1591*100
# Out:
# 6.78818353236958

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %%
X=data.drop(columns=['quality'])
y=data['quality']

# %%
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
x_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=41)

# %%
def metric_score(clf,X_train,X_test,y_train,y_test,train=True):
    if train:
        y_pred=clf.predict(X_train)
        print(f"Accuracy score:{accuracy_score(y_train,y_pred)*100:.2f}%")
        
    elif train==False:
        pred=clf.predict(X_test)
        
        print(f"Accuracy score:{accuracy_score(y_test,pred)*100:.2f}%")
            
        print(classification_report(y_test,pred,digits=2))

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score,classification_report
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
clf=DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
metric_score(clf,X_train,X_test,y_train,y_test,train=True)
metric_score(clf,X_train,X_test,y_train,y_test,train=False)
# Out:
# Accuracy score:100.00%
# Accuracy score:62.25%
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00        11
#            5       0.68      0.69      0.69       157
#            6       0.65      0.64      0.64       168
#            7       0.57      0.58      0.57        57
#            8       0.17      0.25      0.20         4
#
#     accuracy                           0.62       400
#    macro avg       0.35      0.36      0.35       400
# weighted avg       0.63      0.62      0.62       400
